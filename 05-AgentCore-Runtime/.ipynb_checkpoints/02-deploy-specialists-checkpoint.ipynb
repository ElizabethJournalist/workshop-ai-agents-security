# %% [markdown]
# # Lab 05.2 — Deploy Specialists
#
# ## Overview
#
# Os 5 specialists ficam em `agents/<setor>/`. Cada um tem prompt embutido (eles JÁ
# são especializados pelo setor).
#
# Após deploy, vamos atualizar o env do SmartAgent para que ele saiba os ARNs.

# %% [markdown]
# ## Pré-requisitos
#
# - ✅ Lab 05.1 (SmartAgent deployado)

# %% [markdown]
# ## Setup

# %%
import sys
sys.path.insert(0, "..")
from shared.utils.config import load_config, save_config, get_region, get_sector
from shared.utils.iam import create_runtime_role
from utils import deploy_runtime, wait_runtime_ready, UTILITY_AGENTS, ensure_s3_bucket

cfg = load_config()
region = get_region()
sector = get_sector()

import boto3
account_id = boto3.client("sts").get_caller_identity()["Account"]
s3_bucket = f"workshop-agents-{account_id}"
ensure_s3_bucket(s3_bucket, region=region)
# Out:
#   ~ Bucket existe: workshop-agents-354820845663

# %% [markdown]
# ## Passo 1: Deploy dos 5 specialists em paralelo (sequencial neste lab)

# %%
results = {}

for runtime_name, agent_file, env_var, entry in UTILITY_AGENTS[1:]:  # skip SmartAgent
    print(f"\n=== {runtime_name} ===")
    role_arn = create_runtime_role(runtime_name, region=region)
    result = deploy_runtime(
        name=runtime_name,
        agent_py=f"agents/{sector}/{agent_file}",
        req_file=f"agents/{sector}/requirements.txt",
        role_arn=role_arn,
        s3_bucket=s3_bucket,
        sector=sector,
        cognito_pool_id=cfg["COGNITO_USER_POOL_ID"],
        cognito_client_id=cfg["COGNITO_CLIENT_ID"],
        region=region,
        entry_point=entry,
        env_vars={
            "SECTOR": sector,
            "DEMO_SECTOR": sector,
            "AGENTCORE_GATEWAY_URL": cfg.get("GATEWAY_URL", ""),
            "AGENTCORE_MEMORY_ID": cfg.get("MEMORY_ID", ""),
            "BEDROCK_MODEL_ID": "us.anthropic.claude-sonnet-4-5-20250929-v1:0",
            "COGNITO_CLIENT_ID": cfg["COGNITO_CLIENT_ID"],
            "AWS_REGION": region,
            "BEDROCK_GUARDRAIL_ID": cfg.get("BEDROCK_GUARDRAIL_ID", ""),
            "BEDROCK_GUARDRAIL_VERSION": cfg.get("BEDROCK_GUARDRAIL_VERSION", "DRAFT"),
        },
    )
    results[runtime_name] = result
# Out:
# === workshop_GridMonitorAgent ===
#   ~ Role já existe: workshop-runtime-workshop_GridMonitorAgent
#   ✓ ZIP: grid_monitor_agent.zip (35.2 MB)
#   ✓ Upload: s3://workshop-agents-354820845663/workshop-agents/workshop_GridMonitorAgent/grid_monitor_agent.zip
#   ~ Runtime existe (workshop_GridMonitorAgent-Ok4wCcChpb), atualizando...
#
# === workshop_MaintenanceAgent ===
#   ~ Role já existe: workshop-runtime-workshop_MaintenanceAgent
#   ✓ ZIP: maintenance_agent.zip (35.2 MB)
#   ✓ Upload: s3://workshop-agents-354820845663/workshop-agents/workshop_MaintenanceAgent/maintenance_agent.zip
#   ~ Runtime existe (workshop_MaintenanceAgent-F4I57M8cbz), atualizando...
#
# === workshop_ContractAgent ===
#   ~ Role já existe: workshop-runtime-workshop_ContractAgent
#   ✓ ZIP: contract_agent.zip (35.2 MB)
#   ✓ Upload: s3://workshop-agents-354820845663/workshop-agents/workshop_ContractAgent/contract_agent.zip
#   ~ Runtime existe (workshop_ContractAgent-gPNXnV3Pfp), atualizando...
#
# === workshop_CustomerBillingAgent ===
#   ~ Role já existe: workshop-runtime-workshop_CustomerBillingAgent
#   ✓ ZIP: billing_agent.zip (35.2 MB)
#   ✓ Upload: s3://workshop-agents-354820845663/workshop-agents/workshop_CustomerBillingAgent/billing_agent.zip
#   ~ Runtime existe (workshop_CustomerBillingAgent-lov4h6G4yT), atualizando...
#
# === workshop_RegulatoryReportAgent ===
#   ~ Role já existe: workshop-runtime-workshop_RegulatoryReportAgent
#   ✓ ZIP: regulatory_agent.zip (35.2 MB)
#   ✓ Upload: s3://workshop-agents-354820845663/workshop-agents/workshop_RegulatoryReportAgent/regulatory_agent.zip
#   ~ Runtime existe (workshop_RegulatoryReportAgent-eYcQiaEUyf), atualizando...

# %% [markdown]
# ## Passo 2: Aguardar todos READY

# %%
for runtime_name, result in results.items():
    print(f"\nAguardando {runtime_name}...")
    wait_runtime_ready(result["runtime_id"], region=region, timeout=300)
# Out:
# Aguardando workshop_GridMonitorAgent...
#   workshop_GridMonitorAgen... status=READY (0s)
#
# Aguardando workshop_MaintenanceAgent...
#   workshop_MaintenanceAgen... status=READY (0s)
#
# Aguardando workshop_ContractAgent...
#   workshop_ContractAgent-g... status=READY (0s)
#
# Aguardando workshop_CustomerBillingAgent...
#   workshop_CustomerBilling... status=READY (0s)
#
# Aguardando workshop_RegulatoryReportAgent...
#   workshop_RegulatoryRepor... status=READY (0s)

# %% [markdown]
# ## Passo 3: Persistir ARNs em config.env

# %%
updates = {}
for runtime_name, agent_file, env_var, entry in UTILITY_AGENTS[1:]:
    if runtime_name in results:
        updates[env_var] = results[runtime_name]["runtime_arn"]
save_config(updates)
# Out:
#   ✓ config.env atualizado: RUNTIME_BILLING_AGENT_ARN, RUNTIME_CONTRACT_AGENT_ARN, RUNTIME_GRID_AGENT_ARN, RUNTIME_MAINTENANCE_AGENT_ARN, RUNTIME_REGULATORY_AGENT_ARN

# %% [markdown]
# ## Passo 4: Atualizar SmartAgent com os ARNs dos specialists
#
# O SmartAgent precisa das env vars `RUNTIME_<SPECIALIST>_ARN` para chamar HTTPS.
# Re-deploy do smart agent atualiza essas env vars.

# %%
from utils import deploy_runtime

# ARNs dos specialists: usar os mesmos nomes que o smart_agent.py lê
# (RUNTIME_GRID_AGENT_ARN, RUNTIME_MAINTENANCE_AGENT_ARN, RUNTIME_CONTRACT_AGENT_ARN,
#  RUNTIME_BILLING_AGENT_ARN, RUNTIME_REGULATORY_AGENT_ARN)
result = deploy_runtime(
    name="workshop_SmartAgent",
    agent_py="agents/smart_agent.py",
    req_file=f"agents/{sector}/requirements.txt",
    role_arn=cfg["RUNTIME_ROLE_ARN"],
    s3_bucket=s3_bucket,
    sector=sector,
    cognito_pool_id=cfg["COGNITO_USER_POOL_ID"],
    cognito_client_id=cfg["COGNITO_CLIENT_ID"],
    region=region,
    env_vars={
        "SECTOR": sector,
        "DEMO_SECTOR": sector,
        "AGENTCORE_MEMORY_ID": cfg.get("MEMORY_ID", ""),
        "BEDROCK_MODEL_ID": "us.anthropic.claude-haiku-4-5-20251001-v1:0",
        "COGNITO_CLIENT_ID": cfg["COGNITO_CLIENT_ID"],
        "AWS_REGION": region,
            "BEDROCK_GUARDRAIL_ID": cfg.get("BEDROCK_GUARDRAIL_ID", ""),
            "BEDROCK_GUARDRAIL_VERSION": cfg.get("BEDROCK_GUARDRAIL_VERSION", "DRAFT"),
        **{k: v for k, v in updates.items() if v},
    },
)
wait_runtime_ready(result["runtime_id"], region=region, timeout=300)
print("\n✓ SmartAgent atualizado com ARNs dos specialists")
# Out:
#   ✓ ZIP: smart_agent.zip (35.2 MB)
#   ✓ Upload: s3://workshop-agents-354820845663/workshop-agents/workshop_SmartAgent/smart_agent.zip
#   ~ Runtime existe (workshop_SmartAgent-1iW8VTFc6H), atualizando...
#   workshop_SmartAgent-1iW8... status=UPDATING (0s)
#   workshop_SmartAgent-1iW8... status=READY (10s)
#
# ✓ SmartAgent atualizado com ARNs dos specialists

# %% [markdown]
# ## ✅ Validação
#
# Listar todos 6 runtimes do workshop.

# %%
import boto3
client = boto3.client("bedrock-agentcore-control", region_name="us-east-1")
resp = client.list_agent_runtimes()
for r in resp.get("agentRuntimes", []):
     print(r["agentRuntimeName"], r.get("status"))
# Out:
# workshop_SmartAgent READY
# workshop_RegulatoryReportAgent READY
# workshop_MaintenanceAgent READY
# workshop_GridMonitorAgent READY
# workshop_CustomerBillingAgent READY
# workshop_ContractAgent READY

# %% [markdown]
# ## 🎓 O que você aprendeu
#
# - Specialists são deployados individualmente (cada um com seu runtime e role)
# - O SmartAgent é atualizado via re-deploy, recebendo os ARNs dos specialists
#   como env vars (`RUNTIME_*_ARN`) para roteá-los
# - Padrão **Agents as Tools**: o router delega a cada specialist via HTTPS,
#   propagando o JWT do usuário ponta a ponta

# %% [markdown]
# ## Next
#
# ➡️ [05.3 — Invoke Runtime with SSE Streaming](./03-invoke-runtime-with-sse-streaming.ipynb)
